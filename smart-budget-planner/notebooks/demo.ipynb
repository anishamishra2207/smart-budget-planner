# %% [markdown]
# # Smart Budget Planner — Demo Notebook
#
# This notebook is the **proof** that the project is a real agent: it runs
# three scenarios and prints the full step-by-step trace after each one.
# Implementation is not filled in yet — this is the structural skeleton
# approved in the architecture step. Code goes in the marked cells once
# agent.py / tools.py / memory.py are implemented.

# %% [markdown]
# ## Setup
# Load config, create the agent, set the starting monthly balance.

# %%
# TODO:
# from agent import BudgetAgent
# agent = BudgetAgent()
# agent.memory.set_starting_balance(15000)  # ₹15,000 for the month

# %% [markdown]
# ## Scenario 1 — Logging expenses
# Tests `add_expense` and confirms it writes to memory.
# Goal: "I spent ₹500 on groceries and ₹300 on a movie ticket."

# %%
# TODO:
# answer1 = agent.run("I spent ₹500 on groceries and ₹300 on a movie ticket.")
# print("FINAL ANSWER:", answer1)
# agent.memory.print_trace()

# %% [markdown]
# ## Scenario 2 — Summary and category check
# Tests `get_summary` reading memory written in Scenario 1.
# Goal: "How much have I spent on entertainment, and what's my overall summary?"

# %%
# TODO:
# answer2 = agent.run("How much have I spent on entertainment, and what's my overall summary?")
# print("FINAL ANSWER:", answer2)
# agent.memory.print_trace()

# %% [markdown]
# ## Scenario 3 — Affordability decision
# The exact example from the brief. Tests the full plan-act loop: tool call
# -> reasoning over the real result -> decision -> explanation.
# Goal: "Can I afford a ₹2,000 trip?"

# %%
# TODO:
# answer3 = agent.run("Can I afford a ₹2,000 trip?")
# print("FINAL ANSWER:", answer3)
# agent.memory.print_trace()

# %% [markdown]
# ## Viva pointers (fill in once implemented)
# - Plan-act loop deciding the next step: `agent.py`, the loop in `run()`.
# - A tool call, step by step: `tools.py::get_summary`.
# - Memory read back later: Scenario 3's trace using expenses from Scenario 1.
