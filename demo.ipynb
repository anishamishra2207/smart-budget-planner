# %%
from IPython.display import Markdown, display
from agent import BudgetAgent

display(Markdown("## Smart Budget Planner Agent"))
display(Markdown("Initialize one in-memory agent. Its state and conversation history will persist across the next three turns."))
agent = BudgetAgent(total_budget=1000)
print("Agent initialized with total budget: $1000.00")
# Out:
# ## Smart Budget Planner Agent
# Initialize one in-memory agent. Its state and conversation history will persist across the next three turns.
# Agent initialized with total budget: $1000.00

# %%
display(Markdown("### Turn 1: Record expenses"))
user_message = 'I spent 200 on textbooks and 50 on snacks.'
print(f"User: {user_message}")
answer = agent.run_agent_turn(user_message)
print(f"Assistant: {answer}")
# Out:
# ### Turn 1: Record expenses
# User: I spent 200 on textbooks and 50 on snacks.
#   [Step 1 Action] Tool Call -> add_expense({'amount': 200, 'category': 'Education', 'item': 'textbooks'})
#   [Step 1 Observation] Output -> {'message': 'Added textbooks for $200.00.', 'total_spent': 200.0, 'remaining_balance': 800.0, 'overspending': False}
#   [Step 2 Action] Tool Call -> add_expense({'amount': 50, 'category': 'Food', 'item': 'snacks'})
#   [Step 2 Observation] Output -> {'message': 'Added snacks for $50.00.', 'total_spent': 250.0, 'remaining_balance': 750.0, 'overspending': False}
# Assistant: Your expenses have been recorded:
#
# - **Education – Textbooks:** $200
# - **Food – Snacks:** $50
#
# Your updated remaining balance is **$750**. Let me know if you’d like to track any more spending or set a savings goal!

# %%
display(Markdown("### Turn 2: Query current budget"))
user_message = 'How much budget do I have left?'
print(f"User: {user_message}")
answer = agent.run_agent_turn(user_message)
print(f"Assistant: {answer}")
# Out:
# ### Turn 2: Query current budget
# User: How much budget do I have left?
#   [Step 1 Action] Tool Call -> get_summary({'category': None})
#   [Step 1 Observation] Output -> {'total_budget': 1000.0, 'total_spent': 250.0, 'remaining_balance': 750.0, 'category': None, 'category_breakdown': {'Education': 200.0, 'Food': 50.0}, 'savings_goal': None, 'available_after_savings': 750.0, 'overspending': False, 'savings_goal_at_risk': False}
# Assistant: You have **$750** remaining out of your $1,000 budget. Let me know if you’d like to track any other expenses or set a savings goal!

# %%
display(Markdown("### Turn 3: Test affordability reasoning"))
user_message = 'Can I afford a 900 trip?'
print(f"User: {user_message}")
answer = agent.run_agent_turn(user_message)
print(f"Assistant: {answer}")
display(Markdown("The printed `[Step n Action]` and `[Step n Observation]` lines show the agent querying or updating memory before producing each answer."))
# Out:
# ### Turn 3: Test affordability reasoning
# User: Can I afford a 900 trip?
#   [Step 1 Action] Tool Call -> get_summary({'category': None})
#   [Step 1 Observation] Output -> {'total_budget': 1000.0, 'total_spent': 250.0, 'remaining_balance': 750.0, 'category': None, 'category_breakdown': {'Education': 200.0, 'Food': 50.0}, 'savings_goal': None, 'available_after_savings': 750.0, 'overspending': False, 'savings_goal_at_risk': False}
# Assistant: Your current remaining balance is **$750**.
#
# A trip costing **$900** would exceed your budget by **$150**. If you went ahead with it, you would overspend and deplete your entire budget, leaving you with a negative balance of $‑150.
#
# If you’d like to keep within your budget, you could either:
#
# - Reduce the trip cost (e.g., find a cheaper option or cut it down to $750 or less), or
# - Free up additional money by postponing or trimming other expenses.
#
# ...
